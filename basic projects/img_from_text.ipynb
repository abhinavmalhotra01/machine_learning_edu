# %%
import openai
import urllib.request
from PIL import Image
import cv2
# import cv2_imshow

# %%
openai.api_key = "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"

# %%
def gen_img(img_input):
    
    img_response = openai.Image.create(
        prompt= img_input,
        n=1,
        size="256x256"
    )

    img_url = img_response['data'][0]['url']

    urllib.request.urlretrieve(img_url,'img.png')

    img=Image.open('img.png')

    return img

# %%
img_input=input("enter details of img")
out_img =gen_img(img_input)

from IPython.display import Image
Image(filename='img.png')
# Out:
# 2023-01-10 18:25:59.473 message='Request to OpenAI API' method=post path=https://api.openai.com/v1/images/generations
# 2023-01-10 18:26:05.177 message='OpenAI API response' path=https://api.openai.com/v1/images/generations processing_ms=5382 request_id=34e18eb05a49ee04775fc04946aacfac response_code=200
